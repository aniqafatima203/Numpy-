# %%
import numpy as np

# %%
a = [1,2,3,4,5]
arr = np.array([1, 2, 3])
arr
print(arr.dtype)
# Out:
# int64

# %%
# Type casting (Convert one datatype into other)
arr = arr.astype(float)
print(arr)
print(arr.dtype)
# Out:
# [1. 2. 3.]
# float64

# %%
arr = np.array([1.5, 2.9, 3.2])
arr = arr.astype(int)
print(arr)
# Out:
# [1 2 3]

# %%
# Arithematic operations on array 
a = np.array([10,20,30])
b = np.array([1,2,3])
a+b
# Out:
# array([11, 22, 33])

# %%
a-b
# Out:
# array([ 9, 18, 27])

# %%
a*b
# Out:
# array([10, 40, 90])

# %%
a/b
# Out:
# array([10., 10., 10.])

# %%
a**2
# Out:
# array([100, 400, 900])

# %%
# Scalar operations (This function use Broadcasting)
a + 5
# Out:
# array([15, 25, 35])

# %%
# Universal Functions (ufuncs)
arr = np.array([1,4,9,16])
np.sqrt(arr)
# Out:
# array([1., 2., 3., 4.])

# %%
np.exp(arr)
# Out:
# array([2.71828183e+00, 5.45981500e+01, 8.10308393e+03, 8.88611052e+06])

# %%
np.sin(arr)
# Out:
# array([ 0.84147098, -0.7568025 ,  0.41211849, -0.28790332])
